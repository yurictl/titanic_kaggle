# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
titanic_data_train = pd.read_csv('train.csv')
titanic_data_test = pd.read_csv('test.csv')

# %%
X = titanic_data_train.drop(['PassengerId', 'Survived', 'Name' ,'Ticket' , 'Cabin', 'Embarked'], axis = 'columns')
y = titanic_data_train.Survived
X_kaggle = titanic_data_test.drop(['PassengerId', 'Name' ,'Ticket' , 'Cabin', 'Embarked'], axis = 'columns')

# %%
X['SexFact'] = pd.factorize(X['Sex'])[0]
X_kaggle['SexFact'] = pd.factorize(X_kaggle['Sex'])[0]

# %%
X = X.drop(['Sex'], axis = 'columns')
X_kaggle = X_kaggle.drop(['Sex'], axis = 'columns')

# %%
# fill NaN with mean or medium
X = X.fillna({'Age': X.Age.median()})
X_kaggle = X_kaggle.fillna({'Age': X.Age.median()})
X = X.fillna({'Fare': 0})
X_kaggle = X_kaggle.fillna({'Fare': 0})

# %%
# alternative way of filling missing value with test statistic is by using our Imputer method found in sklearn.preprocessing.
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
imp.fit(X)
X = X.fillna(method='bfill')
#This will look for all columns where we have NaN value and replace the NaN value with specified test statistic.
#for mode we specify strategy='most_frequent'

# %%
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
imp.fit(X_kaggle)
X_kaggle = X_kaggle.fillna(method='bfill')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
import autosklearn.classification
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ea59c6fb77f8> in <module>
#       2 import sklearn.datasets
#       3 import sklearn.metrics
# ----> 4 import autosklearn.classification
#
# ModuleNotFoundError: No module named 'autosklearn'

# %%
from sklearn import ensemble

# %%
ctf = ensemble.RandomForestClassifier()

# %%
ctf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
parameters_rf = {'min_samples_leaf': range(1, 10), 'min_samples_split': range(2, 5), 'max_depth': range(1, 20)}

# %%
grid_search_cv_clf = GridSearchCV(clf, parameters_rf, cv = 5)

# %%
grid_search_cv_clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'min_samples_leaf': range(1, 10), 'min_samples_split': range(2, 5), 'max_depth': range(1, 20)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
grid_search_cv_clf.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 3, 'min_samples_split': 2}

# %%
best_clf = grid_search_cv_clf.best_estimator_
best_clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=7,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=3,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
best_clf = grid_search_cv_clf.best_estimator_

# %%
y_kaggle = pd.DataFrame(best_clf.predict(X_kaggle),columns=['Survived'])

# %%
y_kaggle.shape
# Out:
# (418, 1)

# %%
y_kaggle = titanic_data_sest.merge(y_kaggle, left_index=True, right_index = True)

# %%
y_kaggle
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
y_kaggle = y_kaggle[['PassengerId','Survived']].set_index('PassengerId')

# %%
y_kaggle.to_csv('titanic.csv',index=True)
